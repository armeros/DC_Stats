# %% [markdown]
# <a href="https://colab.research.google.com/github/armeros/DC_Stats/blob/main/Exploratory_Data_Analysis_New/Exploratory_Data_Analysis_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
plt.style.use('ggplot')
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # **Initial Exploration**
#
# Exploratory Data Analysis (EDA) is the process of reviewing and cleaning data to derive insight such as
#   - descriptive statistics
#   - correlation
#   - generate hypotheses

# %% [markdown]
# #### **A first look with `df.head()`  (This is what I do first most of the time)**

# %%
books = pd.read_csv('clean_books.csv')
books.head()
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  rating  year        genre
# 0                  JJ Smith     4.7  2016  Non Fiction
# 1              Stephen King     4.6  2011      Fiction
# 2        Jordan B. Peterson     4.7  2018  Non Fiction
# 3             George Orwell     4.7  2017      Fiction
# 4  National Geographic Kids     4.8  2019    Childrens

# %% [markdown]
# ## **Next is to use `df.info()`**

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    350 non-null    object
#  1   author  350 non-null    object
#  2   rating  350 non-null    float64
#  3   year    350 non-null    int64
#  4   genre   350 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 13.8+ KB

# %% [markdown]
# It looks like there are no missing values but we need to dive into each column since missing values might come in other formats, e.g., -999.

# %%
for i in books.columns:
    print(books[i].value_counts(), "\n")
# Out:
# name
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                                                                             1
# 10-Day Green Smoothie Cleanse                                                                                            1
# 11/22/63: A Novel                                                                                                        1
# 12 Rules for Life: An Antidote to Chaos                                                                                  1
# 1984 (Signet Classics)                                                                                                   1
#                                                                                                                         ..
# Alexander Hamilton                                                                                                       1
# Adult Coloring Books: A Coloring Book for Adults Featuring Mandalas and Henna Inspired Flowers, Animals, and Paisley…    1
# Adult Coloring Book: Stress Relieving Patterns                                                                           1
# Adult Coloring Book: Stress Relieving Animal Designs                                                                     1
# Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, Mandalas, Animals, and Paisley Patterns        1
# Name: count, Length: 350, dtype: int64
#
# author
# Jeff Kinney                         12
# Rick Riordan                        10
# Stephenie Meyer                      7
# Bill O'Reilly                        6
# J.K. Rowling                         6
#                                     ..
# The Staff of The Late Show with     1
# Cheryl Strayed                       1
# Ken Follett                          1
# Geneen Roth                          1
# R. J. Palacio                        1
# Name: count, Length: 247, dtype: int64
#
# rating
# 4.8    81
# 4.6    69
# 4.7    64
# 4.5    39
# 4.9    28
# 4.4    26
# 4.3    21
# 4.2     8
# 4.1     5
# 4.0     4
# 3.9     2
# 3.8     1
# 3.6     1
# 3.3     1
# Name: count, dtype: int64
#
# year
# 2009    50
# 2010    40
# 2013    33
# 2011    31
# 2018    30
# 2015    30
# 2012    28
# 2016    27
# 2014    27
# 2017    27
# 2019    27
# Name: count, dtype: int64
#
# genre
# Non Fiction    179
# Fiction        131
# Childrens       40
# Name: count, dtype: int64

# %% [markdown]
# Having checked with **`.value_counts()`** it seems there really is no missing values.
#
# ## **Descriptive statistics**

# %%
books.describe()
# Out:
#            rating         year
# count  350.000000   350.000000
# mean     4.608571  2013.508571
# std      0.226941     3.284711
# min      3.300000  2009.000000
# 25%      4.500000  2010.000000
# 50%      4.600000  2013.000000
# 75%      4.800000  2016.000000
# max      4.900000  2019.000000

# %% [markdown]
# # **Visualizing distribution of data**

# %%
books = pd.read_csv('clean_books.csv')
sns.histplot(data=books, x='rating', color='blue')
plt.show()

# %% [markdown]
# ## **Adjusting histogram bin width**

# %%
sns.histplot(data=books, x='rating', binwidth=0.11)
plt.show()

# %% [markdown]
# ### ***Exercise: Functions for initial exploration***
#
# You are researching unemployment rates worldwide and have been given a new dataset to work with. The data has been saved and loaded for you as a pandas DataFrame called `unemployment`. You've never seen the data before, so your first task is to use a few pandas functions to learn about this new data.
#
# 1. Use a pandas function to print the first five rows of the `unemployment` DataFrame.
# 2. Use a pandas function to print a summary of column non-missing values and data types from the `unemployment` DataFrame.
# 3. Print the summary statistics (count, mean, standard deviation, min, max, and quartile values) of each numerical column in `unemployment`.

# %%
unemployment = pd.read_csv('clean_unemployment.csv')

display(unemployment.head())

print(unemployment.info())

print(unemployment.describe())
# Out:
#   country_code          country_name      continent   2010   2011   2012  \
# 0          AFG           Afghanistan           Asia  11.35  11.05  11.34
# 1          AGO                Angola         Africa   9.43   7.36   7.35
# 2          ALB               Albania         Europe  14.09  13.48  13.38
# 3          ARE  United Arab Emirates           Asia   2.48   2.30   2.18
# 4          ARG             Argentina  South America   7.71   7.18   7.22
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1   7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2  15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3   2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4   7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  182 non-null    object
#  1   country_name  182 non-null    object
#  2   continent     177 non-null    object
#  3   2010          182 non-null    float64
#  4   2011          182 non-null    float64
#  5   2012          182 non-null    float64
#  6   2013          182 non-null    float64
#  7   2014          182 non-null    float64
#  8   2015          182 non-null    float64
#  9   2016          182 non-null    float64
#  10  2017          182 non-null    float64
#  11  2018          182 non-null    float64
#  12  2019          182 non-null    float64
#  13  2020          182 non-null    float64
#  14  2021          182 non-null    float64
# dtypes: float64(12), object(3)
# memory usage: 21.5+ KB
# None
#              2010        2011        2012        2013        2014        2015  \
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean     8.409286    8.315440    8.317967    8.344780    8.179670    8.058901
# std      6.248887    6.266795    6.367270    6.416041    6.284241    6.161170
# min      0.450000    0.320000    0.480000    0.250000    0.200000    0.170000
# 25%      4.015000    3.775000    3.742500    3.692500    3.625000    3.662500
# 50%      6.965000    6.805000    6.690000    6.395000    6.450000    6.170000
# 75%     10.957500   11.045000   11.285000   11.310000   10.695000   10.215000
# max     32.020000   31.380000   31.020000   29.000000   28.030000   27.690000
#
#              2016        2017        2018        2019        2020        2021
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean     7.925879    7.668626    7.426429    7.243736    8.420934    8.390879
# std      6.045439    5.902152    5.818915    5.696573    6.040915    6.067192
# min      0.150000    0.140000    0.110000    0.100000    0.210000    0.260000
# 25%      3.800000    3.690000    3.625000    3.487500    4.285000    4.335000
# 50%      5.925000    5.650000    5.375000    5.240000    6.695000    6.425000
# 75%     10.245000   10.315000    9.257500    9.445000   11.155000   10.840000
# max     26.540000   27.040000   26.910000   28.470000   29.220000   33.560000

# %% [markdown]
# Excellent work—you've now learned that `unemployment` contains 182 rows of country data including `country_code`, `country_name`, `continent`, and unemployment percentages from 2010 through 2021. If you looked very closely, you might have noticed that a few countries are missing information in the `continent` column!

# %% [markdown]
# ### ***Exercise: Counting categorical values***
# Recall from the above that the `unemployment` DataFrame contains 182 rows of country data including `country_code`, `country_name`, `continent`, and unemployment percentages from 2010 through 2021.
#
# You'd now like to explore the categorical data contained in `unemployment` to understand the data that it contains related to each continent.
#
# The `unemployment` DataFrame has been loaded for you along with `pandas` as `pd`.
#
# * Use a `pandas` function to count the values associated with each continent in the `unemployment` DataFrame.

# %%
print(unemployment['continent'].value_counts())
# Out:
# Africa           53
# Asia             47
# Europe           39
# North America    18
# South America    12
# Oceania           8
# Name: continent, dtype: int64

# %% [markdown]
# Did you know that there are 23 countries in North America, which includes countries in the Caribbean and Central America? You may have noticed that North America has 18 data points in the `unemployment` DataFrame, so we are missing information on a few of the countries from our dataset.
#
# ### ***Exercise: Global unemployment in 2021***
#
# What was typical unemployment in a given year? What was the minimum and maximum unemployment rate, and what did the distribution of the unemployment rates look like across the world? A histogram is a great way to get a sense of the answers to these questions.
#
# Your task in this exercise is to create a histogram showing the distribution of global unemployment rates in 2021.
#
# The `unemployment` DataFrame has been loaded for you along with `pandas` as `pd`.
#
# * Create a histogram of the distribution of `2021` `unemployment percentages across all countries in `unemployment`; show a full percentage point in each bin.

# %%
# Create a histogram of 2021 unemployment; show a full percent in each bin
sns.histplot(data=unemployment, x='2021', binwidth=1)
plt.show()

# %% [markdown]
# It looks like 2021 unemployment hovered around 3% to 8% for most countries in the dataset, but a few countries experienced very high unemployment of 20% to 35%.
#
# # **Data Validation**
#
# ```text
# name       object
# author     object
# rating    float64
# year      float64
# genre      object
# dtype: object
# ```
# - `year` should have been `int64`

# %% [markdown]
# ## **Updating data types**

# %%
books = pd.read_csv('clean_books.csv')
books['year'] = books['year'].astype(int)
print(books.dtypes)
# Out:
# name       object
# author     object
# rating    float64
# year        int64
# genre      object
# dtype: object

# %% [markdown]
# ## **Validating categorical data**
#
# - Check whether the categorical variable has inconsistent values

# %%
print(books["genre"].value_counts().sort_index())
# Out:
# genre
# Childrens       40
# Fiction        131
# Non Fiction    179
# Name: count, dtype: int64

# %%
books["genre"].isin(["Fiction", "Non Fiction"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 345     True
# 346     True
# 347     True
# 348     True
# 349    False
# Name: genre, Length: 350, dtype: bool

# %%
books.loc[~books["genre"].isin(["Fiction", "Non Fiction"]), 'genre'].head()
# Out:
# 4     Childrens
# 26    Childrens
# 36    Childrens
# 37    Childrens
# 53    Childrens
# Name: genre, dtype: object

# %%
books["genre"].head()
# Out:
# 0    Non Fiction
# 1        Fiction
# 2    Non Fiction
# 3        Fiction
# 4      Childrens
# Name: genre, dtype: object

# %% [markdown]
# ### **Using `~` operator**

# %%
~books["genre"].isin(["Fiction", "Non Fiction"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 345    False
# 346    False
# 347    False
# 348    False
# 349     True
# Name: genre, Length: 350, dtype: bool

# %% [markdown]
# ## **Select and view only particular types of data**
#
# - Use **`df.select_dtypes()`**

# %%
books.select_dtypes("number").head()
# Out:
#    rating  year
# 0     4.7  2016
# 1     4.6  2011
# 2     4.7  2018
# 3     4.7  2017
# 4     4.8  2019

# %% [markdown]
# ## **Check min, max value**

# %%
print(books['year'].min(), books['year'].max())
# Out:
# 2009 2019

# %% [markdown]
# ## **Check range of data**

# %%
sns.boxplot(data=books, x="year", y="genre"); plt.show()

# %% [markdown]
# It looks like the children's books in our dataset have slightly later publishing years in general, but the range of years is the same for all genres.
#
# ### ***Exercise: Detecting data types***
#
# A column has been changed in the `unemployment` DataFrame and it now has the wrong data type! This data type will stop you from performing effective exploration and analysis, so your task is to identify which column has the wrong data type and then fix it.
#
# `pandas` has been imported as `pd`; `unemployment` is also available.
#
#
# * Which of the columns below requires an update to its data type?

# %%
unemployment.dtypes

# %% [markdown]
# ```
# country_code     object
# country_name     object
# continent        object
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019             object
# 2020            float64
# 2021            float64
# dtype: object
# ```

# %%
# Update the data type of the 2019 column to a float
unemployment["2019"] = unemployment["2019"].astype(float)

# Print the dtypes to check your work
print(unemployment.dtypes)
# Out:
# country_code     object
# country_name     object
# continent        object
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %% [markdown]
# ### ***Exercise: Validating continents***
#
# Your colleague has informed you that the data on unemployment from countries in Oceania is not reliable, and you'd like to identify and exclude these countries from your `unemployment` data. The `.isin()` function can help with that!
#
# Your task is to use `.isin()` to identify countries that are *not* in Oceania. These countries should return `True` while countries in Oceania should return `False`. This will set you up to use the results of `.isin()` to quickly filter out Oceania countries using Boolean indexing.
#
# * Define a Series of Booleans describing whether or not each `continent` is outside of `Oceania`; call this Series `not_oceania`.
# * Use Boolean indexing to print the `unemployment` DataFrame without any of the data related to countries in Oceania.

# %%
# Define a Series describing whether each continent is outside of Oceania
not_oceania = ~unemployment["continent"].isin(["Oceania"])

# Print unemployment without records related to countries in Oceania
display(unemployment[not_oceania])
print(unemployment[not_oceania]['continent'].value_counts(), "\n")
print(unemployment['continent'].value_counts())
# Out:
#     country_code          country_name      continent   2010   2011   2012  \
# 0            AFG           Afghanistan           Asia  11.35  11.05  11.34
# 1            AGO                Angola         Africa   9.43   7.36   7.35
# 2            ALB               Albania         Europe  14.09  13.48  13.38
# 3            ARE  United Arab Emirates           Asia   2.48   2.30   2.18
# 4            ARG             Argentina  South America   7.71   7.18   7.22
# ..           ...                   ...            ...    ...    ...    ...
# 175          VNM               Vietnam           Asia   1.11   1.00   1.03
# 178          YEM           Yemen, Rep.           Asia  12.83  13.23  13.17
# 179          ZAF          South Africa         Africa  24.68  24.64  24.73
# 180          ZMB                Zambia         Africa  13.19  10.55   7.85
# 181          ZWE              Zimbabwe         Africa   5.21   5.37   5.15
#
#       2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0    11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1     7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2    15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3     2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4     7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 175   1.32   1.26   1.85   1.85   1.87   1.16   2.04   2.39   2.17
# 178  13.27  13.47  13.77  13.43  13.30  13.15  13.06  13.39  13.57
# 179  24.56  24.89  25.15  26.54  27.04  26.91  28.47  29.22  33.56
# 180   8.61   9.36  10.13  10.87  11.63  12.01  12.52  12.85  13.03
# 181   4.98   4.77   4.78   4.79   4.78   4.80   4.83   5.35   5.17
#
# [174 rows x 15 columns]
# Africa           53
# Asia             47
# Europe           39
# North America    18
# South America    12
# Name: continent, dtype: int64
#
# Africa           53
# Asia             47
# Europe           39
# North America    18
# South America    12
# Oceania           8
# Name: continent, dtype: int64

# %% [markdown]
# You validated categorical data and used your **`.isin()`** validation to then exclude data that you weren't interested in.  Filtering out data that you don't need at the start of your EDA process is a great way to organize yourself for the exploration.
#
# ### ***Exercise: Validating range***
#
# Now it's time to validate our numerical data. We saw in the previous lesson using `.describe()` that the largest unemployment rate during 2021 was nearly 34 percent, while the lowest was just above zero.
#
# Your task is to get much more detailed information about the range of unemployment data using Seaborn's `boxplot`, and you'll also visualize the range of unemployment rates in each continent to understand geographical range differences.
#
# * Print the minimum and maximum unemployment rates, in that order, during 2021.
# * Create a boxplot of 2021 unemployment rates, broken down by continent.

# %%
# Print the minimum and maximum unemployment rates during 2021
print(unemployment['2021'].min(), unemployment['2021'].max())

# Create a boxplot of 2021 unemployment rates, broken down by continent
sns.boxplot(data=unemployment, x='2021', y='continent')
plt.show()
# Out:
# 0.26 33.56

# %% [markdown]
# Notice how different the ranges in unemployment are between continents. For example, Africa's 50th percentile is lower than that of North America, but the range is much wider.
#
# # **Exploring groups of data**
#
# - Use **`.groupby()`**

# %%
books = pd.read_csv('clean_books.csv')

# ต้องใส่ numeric_only=True สำหรับ pandas version ใหม่ๆ
books.groupby("genre", as_index=False).mean(numeric_only=True)
# Out:
#          genre  rating    year
# 0    Childrens    4.78 2015.08
# 1      Fiction    4.57 2013.02
# 2  Non Fiction    4.60 2013.51

# %%
# If we don't use the keyword argument 'numeric_only=' we need to choose subset
# down to numeric columns manually

books[['genre', 'rating', 'year']].groupby('genre').mean()
# Out:
#              rating    year
# genre
# Childrens      4.78 2015.08
# Fiction        4.57 2013.02
# Non Fiction    4.60 2013.51

# %% [markdown]
# ## **Aggregating ungrouped data**
#
# * **`.agg()`** applies aggregating functions across a DataFrame
#   - **`.sum()`**
#   - **`.count()`**
#   - **`.min()`**
#   - **`.max()`**
#   - **`.var()`**
#   - **`.std()`**

# %%
books.drop(columns=['name', 'author', 'genre']).agg(["mean", "std"])
# Out:
#       rating    year
# mean    4.61 2013.51
# std     0.23    3.28

# %% [markdown]
# ## **Use dictionary to specify aggregate functions**

# %%
books.agg({"rating": ["mean", "std"], "year": ["median"]})
# Out:
#         rating    year
# mean      4.61     NaN
# std       0.23     NaN
# median     NaN 2013.00

# %% [markdown]
# ## **Named summary columns**
#
# We can create named columns with our desired aggregations by using the **`.agg`** function and creating named tuples inside it. Each named tuple should include a column name followed by the aggregating function to apply to that column. The name of the tuple becomes the name of the resulting column.

# %%
books.groupby("genre").agg(mean_rating=("rating", "mean"),
                           std_rating=("rating", "std"),
                           median_year=("year", "median"))
# Out:
#              mean_rating  std_rating  median_year
# genre
# Childrens           4.78        0.12      2015.00
# Fiction             4.57        0.28      2013.00
# Non Fiction         4.60        0.18      2013.00

# %% [markdown]
# ## **Visualizing categorical summaries**
#
# * barplot displays mean of each group

# %%
books.groupby('genre', as_index=False)['rating'].mean()
# Out:
#          genre  rating
# 0    Childrens    4.78
# 1      Fiction    4.57
# 2  Non Fiction    4.60

# %%
list(books.groupby('genre')['rating'].mean())[::-1]
# Out:
# [4.598324022346369, 4.570229007633588, 4.779999999999999]

# %%
ax = sns.barplot(data=books, x="genre", y="rating")
y = list(books.groupby('genre')['rating'].mean())[::-1] # For some unknown reason the ordering is reverse, hence the use of [::-1]
for i, v in enumerate(y):
    ax.text(i, v, '{:.2f}'.format(v), ha='center', va='bottom')
plt.show()

# %% [markdown]
# ### ***Exercise: Summaries with `.groupby()` and `.agg()`***
#
# Explore the means and standard deviations of the yearly unemployment data. First, you'll find means and standard deviations regardless of the continent to observe worldwide unemployment trends. Then, you'll check unemployment trends broken down by continent.
#
#
# * Print the mean and standard deviation of the unemployment rates for each year.
# * Print the mean and standard deviation of the unemployment rates for each year, grouped by continent.

# %%
# Print the mean and standard deviation of rates by year
unemployment.drop(columns=['country_code', 'country_name', 'continent']).agg(['mean', 'std'])
# Out:
#           2010      2011      2012      2013      2014      2015      2016  \
# mean  8.409286  8.315440  8.317967  8.344780  8.179670  8.058901  7.925879
# std   6.248887  6.266795  6.367270  6.416041  6.284241  6.161170  6.045439
#
#           2017      2018      2019      2020      2021
# mean  7.668626  7.426429  7.243736  8.420934  8.390879
# std   5.902152  5.818915  5.696573  6.040915  6.067192

# %%
# Print yearly mean and standard deviation grouped by continent
unemployment.drop(columns=['country_code', 'country_name']).groupby('continent').agg(['mean', 'std'])
# Out:
#                     2010                 2011                 2012            \
#                     mean       std       mean       std       mean       std
# continent
# Africa          9.343585  7.411259   9.369245  7.401556   9.240755  7.264542
# Asia            6.240638  5.146175   5.942128  4.779575   5.835319  4.756904
# Europe         11.008205  6.392063  10.947949  6.539538  11.325641  7.003527
# North America   8.663333  5.115805   8.563333  5.377041   8.448889  5.495819
# Oceania         3.622500  2.054721   3.647500  2.008466   4.103750  2.723118
# South America   6.870833  2.807058   6.518333  2.801577   6.410833  2.936508
#
#                     2013                 2014            ...      2017  \
#                     mean       std       mean       std  ...      mean
# continent                                                ...
# Africa          9.132453  7.309285   9.121321  7.291359  ...  9.284528
# Asia            5.852128  4.668405   5.853191  4.681301  ...  6.171277
# Europe         11.466667  6.969209  10.971282  6.759765  ...  8.359744
# North America   8.840556  6.081829   8.512222  5.801927  ...  7.391111
# Oceania         3.980000  2.640119   3.976250  2.659205  ...  3.872500
# South America   6.335000  2.808780   6.347500  2.834332  ...  7.281667
#
#                              2018                2019                 2020  \
#                     std      mean       std      mean       std       mean
# continent
# Africa         7.407620  9.237925  7.358425  9.264340  7.455293  10.307736
# Asia           5.277201  6.090213  5.409128  5.949149  5.254008   7.012340
# Europe         5.177845  7.427436  4.738206  6.764359  4.124734   7.470513
# North America  5.326446  7.281111  5.253180  7.095000  4.770490   9.297778
# Oceania        2.492834  3.851250  2.455893  3.773750  2.369068   4.273750
# South America  3.398994  7.496667  3.408856  7.719167  3.379845  10.275000
#
#                               2021
#                     std       mean       std
# continent
# Africa         7.928166  10.473585  8.131636
# Asia           5.699609   6.906170  5.414745
# Europe         4.071218   7.414872  3.947825
# North America  4.963045   9.155000  5.076482
# Oceania        2.617490   4.280000  2.671522
# South America  3.411263   9.924167  3.611624
#
# [6 rows x 24 columns]

# %% [markdown]
#  This data is well-summarized, but it's a little long. What if you wanted to focus on a summary for just one year and make it more readable?
#
# ### ***Exercise: Named aggregations***
#
# You've seen how **`.groupby()`** and **`.agg()`** can be combined to show summaries across categories. Sometimes, it's helpful to name new columns when aggregating so that it's clear in the code output what aggregations are being applied and where.
#
# Your task is to create a DataFrame called `continent_summary` which shows a row for each continent. The DataFrame columns will contain the mean unemployment rate for each continent in `2021` as well as the standard deviation of the `2021` unemployment rate. And of course, you'll rename the columns so that their contents are clear!
#
# * Create a column called `mean_rate_2021` which shows the mean 2021 unemployment rate for each continent.
# * Create a column called `std_rate_2021` which shows the standard deviation of the 2021 unemployment rate for each continent.

# %%
continent_summary = unemployment.groupby("continent").agg(
    mean_rate_2021=('2021', 'mean'),  std_rate_2021=('2021', 'std'))

continent_summary
# Out:
#                mean_rate_2021  std_rate_2021
# continent
# Africa              10.473585       8.131636
# Asia                 6.906170       5.414745
# Europe               7.414872       3.947825
# North America        9.155000       5.076482
# Oceania              4.280000       2.671522
# South America        9.924167       3.611624

# %% [markdown]
# Average 2021 unemployment varied widely by continent, and so did the unemployment within those continents.
#
# ### ***Exercise: Visualizing categorical summaries***
#
# In Seaborn, bar plots include a vertical bar indicating the 95% confidence interval for the categorical mean. Since confidence intervals are calculated using both the number of values and the variability of those values, they give a helpful indication of how much data can be relied upon.
#
# * Create a bar plot showing continents on the x-axis and their respective average 2021 unemployment rates on the y-axis.

# %%
# Create a bar plot of continents and their average unemployment
sns.barplot(data=unemployment, x='continent', y='2021')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# While Europe has higher average unemployment than Asia, it also has a smaller confidence interval for that average, so the average value is more reliable.
#
# ทำกราฟให้ดูดีขึ้น เตรียมข้อมูล

# %%
unemployment = pd.read_csv('clean_unemployment.csv')
grouped = unemployment.groupby('continent')['2021'].mean()

# Print groupby table
print(grouped, "\n")
x = [i for i in grouped.index]
y = [i for i in grouped]
print(x, "\n")
print(y)
# Out:
# continent
# Africa          10.47
# Asia             6.91
# Europe           7.41
# North America    9.15
# Oceania          4.28
# South America    9.92
# Name: 2021, dtype: float64
#
# ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']
#
# [10.473584905660378, 6.906170212765957, 7.414871794871795, 9.155, 4.28, 9.924166666666666]

# %%
data = {'continent': x, '2021': y}

ax = sns.barplot(x='continent', y='2021', data=data)
plt.xticks(rotation=45)
plt.gca().set_xticklabels(sorted(data['continent']))

for i, v in enumerate(y):
    ax.text(i, v, '{:.2f}'.format(v), ha='center', va='bottom')

plt.show()
# Out:
# /tmp/ipykernel_1772/1066171847.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(sorted(data['continent']))

# %% [markdown]
# # **Checking for missing values**
#
# - Missing data skew the distribution
# - Less representative of the underlying population
#
# ![image.png](data:image/png;base64,...)

# %%
# Complete data
salaries = pd.read_csv('ds_salaries_clean.csv')
display(salaries.isnull().any())
sns.boxplot(data=salaries, x='Experience', y='Salary_USD', hue='Experience',
            order=['Executive', 'Senior', 'Mid', 'Entry'],
            hue_order=['Executive', 'Senior', 'Mid', 'Entry']); plt.show();
# Out:
# Working_Year            False
# Designation             False
# Experience              False
# Employment_Status       False
# Employee_Location       False
# Company_Size            False
# Remote_Working_Ratio    False
# Salary_USD              False
# dtype: bool

# %% [markdown]
# ***Incomplete data***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Strategies for addressing missing data**
#
# * Drop missing values
#   * 5% or less of total values
# * Impute mean, median, mode
#   * Depends on distribution and context
# * Impute by sub-group
#   * Different experience levels have different median salary

# %% [markdown]
# ## **Dropping missing values**
#
# * ทิ้งค่าข้อมูลที่หายไปของตัวแปร (คอลัมน์) นั้นๆได้ ถ้าหากตัวแปรนั้นมีค่าที่หายไปน้อยกว่า threshold ถ้าหายไปมากกว่าก็จะไม่สามารถทิ้งได้

# %%
threshold = len(salaries) * 0.05
print(threshold)
# Out:
# 30.35

# %% [markdown]
# ## **Drop "columns" that contain too many missing values**
#
# Typically, you would want to drop rows based on columns that have a high percentage of missing values.

# %%
cols_to_drop = salaries.columns[salaries.isna().sum() <= threshold]
print(cols_to_drop)

# This data has been cleansed so there was no missing
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## **Drop "missing values" for columns that have few missing values**

# %%
cols_to_drop = salaries.columns[salaries.isna().sum() <= threshold] # Note the change in equality
salaries.dropna(subset=cols_to_drop, inplace=True)
salaries.head()
# Out:
#    Working_Year                 Designation Experience Employment_Status  \
# 0          2020              Data Scientist        Mid                FT
# 1          2020  Machine Learning Scientist     Senior                FT
# 2          2020           Big Data Engineer     Senior                FT
# 3          2020        Product Data Analyst        Mid                FT
# 4          2020   Machine Learning Engineer     Senior                FT
#
#   Employee_Location Company_Size  Remote_Working_Ratio  Salary_USD
# 0                DE            L                     0    76227.00
# 1                JP            S                     0   248257.00
# 2                GB            M                    50   104100.00
# 3                HN            S                     0    19097.00
# 4                US            L                    50   143225.00

# %% [markdown]
# # **Imputing a summary statistic**

# %%
cols_with_missing_values = salaries.columns[salaries.isna().sum() > 0]
print(cols_with_missing_values)
# Out:
# Index([], dtype='object')

# %% [markdown]
# `salaries[col].mode()` จะออกมาในรูป Series เลยต้องใส่ `[0]`
#
#
#
# ```
# salaries['Salary_USD'].mode()
#
# 0    95483.0
# Name: Salary_USD, dtype: float64
# ```
#
# ```
# salaries['Experience'].mode()
#
# 0    Senior
# Name: Experience, dtype: object
# ```

# %%
for col in cols_with_missing_values[:-1]:
    salaries[col].fillna(salaries[col].mode()[0])

# %% [markdown]
# # **Imputing by sub-group**

# %%
salaries_dict = salaries.groupby("Experience")["Salary_USD"].median().to_dict()
print(salaries_dict)
# Out:
# {'Entry': 53948.0, 'Executive': 163694.5, 'Mid': 73465.0, 'Senior': 129380.0}

# %%
salaries["Experience"]
# Out:
# 0         Mid
# 1      Senior
# 2      Senior
# 3         Mid
# 4      Senior
#         ...
# 602    Senior
# 603    Senior
# 604    Senior
# 605    Senior
# 606       Mid
# Name: Experience, Length: 607, dtype: object

# %%
salaries["Experience"].map(salaries_dict)
# Out:
# 0      73465.00
# 1     129380.00
# 2     129380.00
# 3      73465.00
# 4     129380.00
#          ...
# 602   129380.00
# 603   129380.00
# 604   129380.00
# 605   129380.00
# 606    73465.00
# Name: Experience, Length: 607, dtype: float64

# %%
# Impute by category

salaries["Salary_USD"] = salaries["Salary_USD"].fillna(salaries["Experience"].map(salaries_dict))

# %% [markdown]
# ### ***Exercise: Dealing with missing data***
#
# It is important to deal with missing data ***BEFORE*** starting your analysis.
#
# One approach is to drop missing values if they account for a small proportion, typically five percent, of your data.
#
# Working with a dataset on plane ticket prices, stored as a pandas DataFrame called `planes`, you'll need to count the number of missing values across all columns, calculate five percent of all values, use this threshold to remove observations, and check how many missing values remain in the dataset.
#
# * Print the number of missing values in each column of the DataFrame.

# %%
# Count the number of missing values in each column
planes = pd.read_csv('planes.csv')
print(planes.isna().sum())
# Out:
# Airline            427
# Date_of_Journey    322
# Source             187
# Destination        347
# Route              256
# Dep_Time           260
# Arrival_Time       194
# Duration           214
# Total_Stops        212
# Additional_Info    589
# Price              616
# dtype: int64

# %% [markdown]
# * Calculate how many observations five percent of the planes DataFrame is equal to.
# * Create `cols_to_drop` by applying boolean indexing to columns of the DataFrame with missing values less than or equal to the threshold.
# * Use this filter to remove missing values and save the updated DataFrame.

# %%
# Find the five percent threshold
threshold = len(planes) * 0.05

# Create a filter
cols_to_drop = planes.columns[planes.isnull().sum() <= threshold]

# Drop missing values for columns below the threshold
planes.dropna(subset=cols_to_drop, inplace=True)

print(planes.isna().sum())
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                0
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          0
# Additional_Info    300
# Price              368
# dtype: int64

# %% [markdown]
# You've managed to remove missing values from all columns except for `Additional_Info` and `Price`.
#
# ### ***Strategies for remaining missing data***
#
# The five percent rule has worked nicely for your planes dataset, eliminating missing values from nine out of 11 columns!
#
# Now, you need to decide what to do with the `"Additional_Info"` and `"Price"` columns, which are missing `300` and `368` values respectively.
#
# You'll first take a look at what `"Additional_Info"` contains, then visualize the price of plane tickets by different airlines.
#
#
# * Print the values and frequencies of `"Additional_Info"`.

# %%
planes["Additional_Info"].value_counts()
# Out:
# Additional_Info
# No info                         6399
# In-flight meal not included     1525
# No check-in baggage included     258
# 1 Long layover                    14
# Change airports                    7
# No Info                            2
# Business class                     1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %% [markdown]
# * Create a boxplot of `"Price"` by `"Airline"`.

# %%
# Create a box plot of Price by Airline
sns.boxplot(data=planes, x="Airline", y='Price', hue='Airline')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Question**
#   * How should you deal with the missing values in `"Additional_Info"` and `"Price"`?
#
# **Answer**
#   * You don't need the `"Additional_Info"` column, and should impute <u>median</u> `"Price"` by `"Airline"` to accurately represent the data. (The `"Price"` distributions by `"Airline"` appear to have extreme values, so the *mean* isn't the best descriptive statistic to impute.)
#
# ### ***Exercise: Imputing missing plane prices***
#
# Now there's just one column with missing values left!
#
# You've removed the `"Additional_Info"` column from planes—the last step is to impute the missing data in the `"Price"` column of the dataset.
#
# The above boxplot suggested that imputing the **`median`** price based on the `"Airline"` is a solid approach.
#
# * Group `planes` by airline and calculate the median price.

# %%
airline_prices = planes.groupby("Airline")["Price"].median()
airline_prices
# Out:
# Airline
# Air Asia             5192.00
# Air India            9443.00
# GoAir                5003.50
# IndiGo               5054.00
# Jet Airways         11507.00
# Multiple carriers   10197.00
# SpiceJet             3873.00
# Vistara              8028.00
# Name: Price, dtype: float64

# %% [markdown]
# * Convert the grouped median prices to a dictionary.

# %%
prices_dict = airline_prices.to_dict()
prices_dict
# Out:
# {'Air Asia': 5192.0,
#  'Air India': 9443.0,
#  'GoAir': 5003.5,
#  'IndiGo': 5054.0,
#  'Jet Airways': 11507.0,
#  'Multiple carriers': 10197.0,
#  'SpiceJet': 3873.0,
#  'Vistara': 8028.0}

# %% [markdown]
# * Conditionally impute missing values for `"Price"` by mapping values in the `"Airline column"` based on `prices_dict`.
# * Check for remaining missing values.

# %%
# Map the dictionary to missing values of Price by Airline
planes["Price"] = planes["Price"].fillna(planes["Airline"].map(prices_dict))

# Check for missing values
print(planes.isnull().sum())
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                0
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          0
# Additional_Info    300
# Price                0
# dtype: int64

# %% [markdown]
# You converted a grouped DataFrame to a dictionary and then used it to conditionally fill missing values for `"Price"` based on the `"Airline"`
#
# # **Converting and analyzing categorical data**
#
# บางครั้งข้อมูล text มันหลากหลายเกินไป ทำให้ดูภาพรวมยาก จึงต้องมาจัดรวมให้เป็นหมวดหมู่ใหญ่ๆดังนี้
#
#
# ## **Preview data**

# %%
salaries = pd.read_csv('ds_salaries_clean.csv')
salaries.select_dtypes("object").head()
# Out:
#                   Designation Experience Employment_Status Employee_Location  \
# 0              Data Scientist        Mid                FT                DE
# 1  Machine Learning Scientist     Senior                FT                JP
# 2           Big Data Engineer     Senior                FT                GB
# 3        Product Data Analyst        Mid                FT                HN
# 4   Machine Learning Engineer     Senior                FT                US
#
#   Company_Size
# 0            L
# 1            S
# 2            M
# 3            S
# 4            L

# %%
salaries["Designation"].value_counts()
# Out:
# Designation
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Machine Learning Scientist                    8
# Big Data Engineer                             8
# Director of Data Science                      7
# AI Scientist                                  7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Data Analytics Manager                        7
# BI Data Analyst                               6
# Computer Vision Engineer                      6
# ML Engineer                                   6
# Lead Data Engineer                            6
# Applied Data Scientist                        5
# Business Data Analyst                         5
# Data Engineering Manager                      5
# Head of Data                                  5
# Data Analytics Engineer                       4
# Head of Data Science                          4
# Applied Machine Learning Scientist            4
# Analytics Engineer                            4
# Machine Learning Developer                    3
# Data Science Engineer                         3
# Lead Data Analyst                             3
# Machine Learning Infrastructure Engineer      3
# Lead Data Scientist                           3
# Principal Data Engineer                       3
# Computer Vision Software Engineer             3
# Product Data Analyst                          2
# ETL Developer                                 2
# Cloud Data Engineer                           2
# Financial Data Analyst                        2
# Director of Data Engineering                  2
# Principal Data Analyst                        2
# Machine Learning Manager                      1
# Marketing Data Analyst                        1
# 3D Computer Vision Researcher                 1
# Finance Data Analyst                          1
# Data Specialist                               1
# Staff Data Scientist                          1
# Big Data Architect                            1
# Head of Machine Learning                      1
# NLP Engineer                                  1
# Lead Machine Learning Engineer                1
# Data Analytics Lead                           1
# Name: count, dtype: int64

# %%
salaries["Designation"].nunique()
# Out:
# 50

# %% [markdown]
# There are way too many categories!

# %%
sns.barplot(x=salaries["Designation"].value_counts().head().index,
            y=salaries["Designation"].value_counts().head().values,
            palette="Set1", hue=salaries["Designation"].value_counts().head().index)
plt.xticks(rotation=45)
plt.title('Top 5 most common data professional job titles')
plt.show()

# %%
# If plotted by pandas
salaries["Designation"].value_counts().head().plot(kind='bar')
plt.show()

# %% [markdown]
# # **Extracting value from categories**
#
# - **`pandas.Series.str.contains()`**
# - If lots of categories come from various format or typo, use package **`thefuzz`**

# %%
# Find job titles contains the word 'scientist'
salaries.loc[salaries["Designation"].str.contains("Scientist"), 'Designation']
# Out:
# 0                  Data Scientist
# 1      Machine Learning Scientist
# 6             Lead Data Scientist
# 7                  Data Scientist
# 10                 Data Scientist
#                   ...
# 593                Data Scientist
# 596                Data Scientist
# 598                Data Scientist
# 599                Data Scientist
# 606                  AI Scientist
# Name: Designation, Length: 194, dtype: object

# %% [markdown]
# # **Finding multiple phrases in strings**

# %%
salaries.loc[salaries["Designation"].str.contains("Machine Learning|AI"), 'Designation']
# Out:
# 1              Machine Learning Scientist
# 4               Machine Learning Engineer
# 20              Machine Learning Engineer
# 29               Machine Learning Manager
# 37              Machine Learning Engineer
#                       ...
# 506    Applied Machine Learning Scientist
# 513             Machine Learning Engineer
# 532             Machine Learning Engineer
# 533             Machine Learning Engineer
# 606                          AI Scientist
# Name: Designation, Length: 69, dtype: object

# %% [markdown]
# ## **Finding words of interest**
#
# * Any word that <u>start</u> with `Data`.
#    - '`^`' indicates the start of string
#
# E.g., Big Data Engineer is not counted.

# %%
salaries.loc[salaries['Designation'].str.contains('^Data'), 'Designation']
# Out:
# 0      Data Scientist
# 5        Data Analyst
# 7      Data Scientist
# 10     Data Scientist
# 11     Data Scientist
#             ...
# 601      Data Analyst
# 602     Data Engineer
# 603     Data Engineer
# 604      Data Analyst
# 605      Data Analyst
# Name: Designation, Length: 423, dtype: object

# %% [markdown]
# ## **Finding multiple phrases in string**

# %%
job_categories = ["Data Science", "Data Analytics", "Data Engineering",
                  "Machine Learning", "Managerial", "Consultant"]

data_science = "Data Scientist|NLP"
data_analyst = "Analyst|Analytics"
data_engineer = "Data Engineer|ETL|Architect|Infrastructure"
ml_engineer = "Machine Learning|ML|Big Data|AI"
manager = "Manager|Head|Director|Lead|Principal|Staff"
consultant = "Consultant|Freelance"

conditions = [(salaries["Designation"].str.contains(data_science)),
              (salaries["Designation"].str.contains(data_analyst)),
              (salaries["Designation"].str.contains(data_engineer)),
              (salaries["Designation"].str.contains(ml_engineer)),
              (salaries["Designation"].str.contains(manager)),
              (salaries["Designation"].str.contains(consultant))]

salaries["Job_Category"] = np.select(conditions,
                                     job_categories,
                                     default="Other")

salaries[["Designation", "Job_Category"]].head()
# Out:
#                   Designation      Job_Category
# 0              Data Scientist      Data Science
# 1  Machine Learning Scientist  Machine Learning
# 2           Big Data Engineer  Data Engineering
# 3        Product Data Analyst    Data Analytics
# 4   Machine Learning Engineer  Machine Learning

# %% [markdown]
# ## **Visualizing job category frequency**

# %%
category_counts = salaries["Job_Category"].value_counts()
category_order = category_counts.index

sns.countplot(data=salaries, x="Job_Category", order=category_order, hue='Job_Category')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ### ***Exercise: Finding the number of unique values***
#
# To help identify which data could be reformatted to extract value, you are going to find out which non-numeric columns in the planes dataset have a *large number of unique values*.
#
# * Filter `planes` for columns that are of `"object"` data type.
# * Loop through the columns in the dataset.
# * Add the column iterator to the print statement, then call the function to return the number of unique values in the column.

# %%
planes = pd.read_csv('planes.csv')
# Filter the DataFrame for object columns
non_numeric = planes.select_dtypes("object")

# Loop through columns
for i in non_numeric.columns:

  # Print the number of unique values
  print(f"Number of unique values in {i} column: ", non_numeric[i].nunique())
# Out:
# Number of unique values in Airline column:  8
# Number of unique values in Date_of_Journey column:  44
# Number of unique values in Source column:  5
# Number of unique values in Destination column:  6
# Number of unique values in Route column:  126
# Number of unique values in Dep_Time column:  221
# Number of unique values in Arrival_Time column:  1334
# Number of unique values in Duration column:  367
# Number of unique values in Total_Stops column:  5
# Number of unique values in Additional_Info column:  10

# %% [markdown]
# Interestingly, `"Duration"` is currently an object column whereas it should be a numeric column, and has 362 unique values! Let's find out more about this column.
#
# ### ***Exercise: Flight duration categories***
#
# Calling `planes["Duration"].head()`, we see the following values:
#
#
# ```
# 0        19h
# 1     5h 25m
# 2     4h 45m
# 3     2h 25m
# 4    15h 30m
# Name: Duration, dtype: object
# ```
#
#
# Looks like this won't be simple to convert to numbers. However, you could categorize flights by duration and examine the frequency of different flight lengths!
#
# You'll create a `"Duration_Category"` column in the `planes` DataFrame. Before you can do this you'll need to create a list of the values you would like to insert into the DataFrame, followed by the existing values that these should be created from.
#
# * Create a list of categories containing `"Short-haul"`, `"Medium"`, and `"Long-haul"`.
# * Create `short_flights`, a string to capture values of `"0h"`, `"1h"`, `"2h"`, `"3h"`, or `"4h"`.
# * Create `medium_flights` to capture any values between five and nine hours.
# * Create `long_flights` to capture any values from `10` hours to `16` hours inclusive.

# %%
# Create a list of categories
flight_categories = ["Short-haul", "Medium", "Long-haul"]

# Create short-haul values
short_flights = '^0h|^1h|^2h|^3h|^4h'

# Create medium-haul values
medium_flights = '^5h|^6h|^7h|^8h|^9h'

# Create long-haul values
long_flights = '10h|11h|12h|13h|14h|15h|16h'

# %% [markdown]
# ### ***Exercise: Adding duration categories***
#
# Now that you've set up the categories and values you want to capture, it's time to build a new column to analyze the frequency of flights by duration!
#
# Additionally, the following packages have been imported: pandas as pd, numpy as np, seaborn as sns, and matplotlib.pyplot as plt.
#
# * Create `conditions`, a list containing subsets of `planes["Duration"]` based on `short_flights`, `medium_flights`, and `long_flights`.
#
# * Create the `"Duration_Category"` column by calling a function that accepts your `conditions` list and `flight_categories`, setting values not found to `"Extreme duration"`.
# * Create a plot showing the count of each category.

# %%
# Create conditions for values in flight_categories to be created

####  YOU NEED TO DEAL WITH MISSING DATA FROM ABOVE BEFORE RUNNING THIS

conditions = [(planes["Duration"].str.contains(short_flights)),
              (planes["Duration"].str.contains(medium_flights)),
              (planes["Duration"].str.contains(long_flights))]

# Apply the conditions list to the flight_categories
planes["Duration_Category"] = np.select(conditions,
                                        flight_categories,
                                        default="Extreme duration")

# Plot the counts of each category
sns.countplot(data=planes, x="Duration_Category", hue='Duration_Category')
plt.show()

# %% [markdown]
# Creative categorical transformation work! It's clear that the majority of flights are short-haul, and virtually none are longer than 16 hours!
#
# # **Working with numeric data**
#
# ## **Converting comma separated string of numbers into int or float**

# %%
salaries = pd.read_csv("ds_salaries_clean.csv")
salaries.info()  # Do not run.  Below is different dataset.

# %% [markdown]
# ```text
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
#
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Working_Year          594 non-null    int64
#  1   Designation           567 non-null    object
#  2   Experience            561 non-null    object
#  3   Employment_Status     563 non-null    object
#  4   Salary_In_Rupees      566 non-null    object  <==============
#  5   Employee_Location     554 non-null    object
#  6   Company_Location      570 non-null    object
#  7   Company_Size          535 non-null    object
#  8   Remote_Working_Ratio  571 non-null    float64
#
# dtypes: float64(1), int64(1), object(7)
# memory usage: 41.9+ KB
#
# None
# ```
#
# - Remove comma `','` in `Salary_In_Rupees`
# - Convert the column to `float`
# - Create new column by converting the currency

# %%
df['col'].str.replace("characters to remove", "characters to replace them with")

salaries['Salary_In_Rupees'] = salaries['Salary_In_Rupees'].str.replace(',', '')

# %% [markdown]
# ## **Converting strings to numbers**

# %%
df['col'].astype(float)

salaries['Salary_In_Rupees'] = salaries['Salary_In_Rupees'].astype('float')

# 1 Rupee = 0.012 USD
salaries['Salary_USD'] = salaries['Salary_In_Rupees'] *  0.012

# %% [markdown]
# ## **Adding summary statistics into a DataFrame**

# %% [markdown]
# salaries.info()

# %%
salaries.groupby('Company_Size')['Salary_USD'].mean()
# Out:
# Company_Size
# L   113,857.28
# M   111,625.33
# S    74,126.31
# Name: Salary_USD, dtype: float64

# %% [markdown]
# # **ใส่ aggregated statistics ลงไปในตาราง (นำตัวเลขจากตาราง groupby มาใส่ในตาราง)**
#
# ![image.png](data:image/png;base64,...)

# %%
salaries.groupby("Experience")["Salary_USD"].agg(['std', 'count']).sort_values(by='count', ascending=False)
# Out:
#                   std  count
# Experience
# Senior      55,086.26    280
# Mid         61,014.88    213
# Entry       42,390.36     88
# Executive  111,783.58     26

# %%
salaries["std_dev"] = salaries.groupby("Experience")["Salary_USD"].transform(lambda x: x.std())
# salaries["std_dev"] = salaries.groupby("Experience")["Salary_USD"].transform("std")
print(salaries[["Experience", "std_dev"]].value_counts(), "\n")
salaries[["Experience", "std_dev"]].head()
# Out:
# Experience  std_dev
# Senior      55,086.26     280
# Mid         61,014.88     213
# Entry       42,390.36      88
# Executive   111,783.58     26
# Name: count, dtype: int64
#   Experience   std_dev
# 0        Mid 61,014.88
# 1     Senior 55,086.26
# 2     Senior 55,086.26
# 3        Mid 61,014.88
# 4     Senior 55,086.26

# %% [markdown]
# ### ***Exercise: Flight duration***
#
# You would like to analyze the duration of flights, but unfortunately, the `"Duration"` column in the `planes` DataFrame currently contains string values.
#
# * Print the first five values of the `"Duration"` column.

# %%
planes = pd.read_csv('planes.csv')
planes["Duration"].head()

# %% [markdown]
# ```
#     0                  19.0h
#     1     5.416666666666667h
#     2                  4.75h
#     3    2.4166666666666665h
#     4                  15.5h
#
#     Name: Duration, dtype: object
# ```

# %% [markdown]
# * Remove `"h"` from the column.
# * Convert the column to `float` data type.
# * Plot a histogram of `"Duration"` values.

# %%
# Remove the string character
planes["Duration"] = planes["Duration"].str.replace("h", "")

# Convert to float data type
planes["Duration"] = planes["Duration"].astype(float)

# Plot a histogram
sns.histplot(data=planes, x='Duration')
plt.show()

# %% [markdown]
# ### ***Supplementary Exercise***
#
# The actual data on 'Duration' column is more complicated.

# %%
planes = pd.read_csv('planes.csv'); planes['Duration'].head()

# Missing data must be dealt with since .transform cannot be used
threshold = len(planes) * 0.05
cols_to_drop = planes.columns[planes.isnull().sum() <= threshold]
planes.dropna(subset=cols_to_drop, inplace=True)
airline_prices = planes.groupby("Airline")["Price"].median()
prices_dict = airline_prices.to_dict()
planes["Price"] = planes["Price"].fillna(planes["Airline"].map(prices_dict))

# Convert Duration column into float
planes['Duration'] = planes['Duration'].str.replace('h|m', '', regex=True)
planes['Duration'] = planes['Duration'].str.split()
planes['Hours'] = planes['Duration'].transform(lambda x: x[0]).astype('float')
planes['Mins'] = planes['Duration'].transform(lambda x: 0 if len(x) == 1 else x[1]).astype('float')
planes['Duration'] = planes['Hours'] + planes['Mins']/ 60

sns.histplot(data=planes, x='Duration')
plt.show()

# %% [markdown]
# ### ***Exercise: Adding descriptive statistics***
#
# Now `"Duration"` and `"Price"` both contain numeric values in the planes DataFrame, you would like to calculate summary statistics for them that are conditional on values in other columns.
#
# - Add a column to `planes` containing the standard deviation of `"Price"` based on `"Airline"`.

# %%
  # Price standard deviation by Airline
planes["airline_price_st_dev"] = planes.groupby("Airline")["Price"].transform('std')

print(planes[["Airline", "airline_price_st_dev"]].value_counts())
# Out:
# Airline            airline_price_st_dev
# Jet Airways        4,159.85                3082
# IndiGo             2,245.53                1632
# Air India          3,692.61                1399
# Multiple carriers  3,558.32                 959
# SpiceJet           1,798.90                 653
# Vistara            2,888.92                 376
# Air Asia           1,979.83                 260
# GoAir              2,764.93                 147
# Name: count, dtype: int64

# %% [markdown]
# * Calculate the median for `"Duration"` by `"Airline"`, storing it as a column called `"airline_median_duration"`.

# %%
# Median Duration by Airline
planes["airline_median_duration"] = planes.groupby("Airline")["Duration"].transform('median')

print(planes[["Airline","airline_median_duration"]].value_counts())
# Out:
# Airline            airline_median_duration
# Jet Airways        13.33                      3082
# IndiGo             2.92                       1632
# Air India          15.50                      1399
# Multiple carriers  10.25                       959
# SpiceJet           2.50                        653
# Vistara            3.17                        376
# Air Asia           2.83                        260
# GoAir              2.92                        147
# Name: count, dtype: int64

# %% [markdown]
# * Find the mean `"Price"` by `"Destination"`, saving it as a column called `"price_destination_mean"`.

# %%
# Mean Price by Destination
planes["price_destination_mean"] = planes.groupby("Destination")["Price"].transform('mean')

print(planes[["Destination","price_destination_mean"]].value_counts())
# Out:
# Destination  price_destination_mean
# Cochin       10,473.59                 3631
# Banglore     9,093.62                  2291
# Delhi        5,248.54                   998
# New Delhi    11,579.31                  720
# Hyderabad    5,190.27                   562
# Kolkata      4,907.16                   306
# Name: count, dtype: int64

# %% [markdown]
# # **Outliers**
#
# - They may not accurately represent the data
# - They skew the mean and standard deviation
# - Hypothesis testing often requires normally distributed data

# %% [markdown]
# ## **Use `.describe()` to see whether we have outliers.**

# %%
salaries = pd.read_csv('ds_salaries_clean.csv')
salaries['Salary_USD'].describe()
# Out:
# count       607.00
# mean    107,225.84
# std      67,752.39
# min       2,730.00
# 25%      59,893.00
# 50%      96,982.00
# 75%     143,225.00
# max     572,900.00
# Name: Salary_USD, dtype: float64

# %% [markdown]
# The maximum salary is more than 5 times of mean and median.
#
# ## **Interquartile range (IQR)**
#
# ![image.png](data:image/png;base64,...)
#
# * IQR = 75th - 25th percentile = `df['data'].quantile(0.75) - df['data'].quantile(0.25)`
#
# * Upper Outliers $>$ 75th percentile + $(1.5 \times IQR)$
#   - `upper = df['data'].quantile(0.75) + 1.5*IQR`
# * Lower Outliers $<$ 25th percentile - $(1.5 \times IQR)$
#   - `lower = df['data'].quantile(0.25) - 1.5*IQR`
#
# # **Identifying outliers**
#
# * `df[(df["data"] < lower) | (df["data"] > upper)]`

# %%
# 75th percentile
seventy_fifth = salaries['Salary_USD'].quantile(0.75)

# 25th percentile
twenty_fifth = salaries['Salary_USD'].quantile(0.25)

# IQR
iqr = seventy_fifth - twenty_fifth

# upper threshold
upper = seventy_fifth + 1.5 * iqr

# lower threshold
lower = twenty_fifth - 1.5 * iqr

print(lower)  # Negative salaries not possible

salaries.loc[(salaries['Salary_USD'] < lower) | (salaries['Salary_USD'] > upper), ['Experience', 'Employee_Location', 'Salary_USD'] ]
# Out:
# -65105.0
#     Experience Employee_Location  Salary_USD
# 25   Executive                US  310,321.00
# 33         Mid                US  429,675.00
# 63      Senior                US  393,392.00
# 97         Mid                US  429,675.00
# 157        Mid                US  403,895.00
# 225  Executive                US  397,211.00
# 252  Executive                US  572,900.00
# 482  Executive                US  309,366.00
# 519     Senior                US  362,837.00
# 523     Senior                US  386,708.00

# %%
# Get rid of outliers
no_outlier = salaries.loc[(salaries['Salary_USD'] > lower) & (salaries['Salary_USD'] < upper), ['Experience', 'Employee_Location', 'Salary_USD'] ]
no_outlier.describe()
# Out:
#        Salary_USD
# count      597.00
# mean   102,328.48
# std     55,910.79
# min      2,730.00
# 25%     59,819.00
# 50%     95,483.00
# 75%    141,565.00
# max    263,534.00

# %% [markdown]
# ## **Distribution when outliers exist**

# %%
salaries = pd.read_csv('ds_salaries_clean.csv')
sns.histplot(data=salaries, x='Salary_USD'); plt.show()

# %%
sns.histplot(data=no_outlier, x='Salary_USD'); plt.show()

# %% [markdown]
# # **Pattern over time**

# %% [markdown]
# ## **Importing DateTime data**

# %%
divorce = pd.read_csv("divorce.csv", parse_dates=["marriage_date", 'divorce_date', 'dob_man', 'dob_woman'])
divorce.dtypes
# Out:
# divorce_date         datetime64[ns]
# dob_man              datetime64[ns]
# education_man                object
# income_man                  float64
# dob_woman            datetime64[ns]
# education_woman              object
# income_woman                float64
# marriage_date        datetime64[ns]
# marriage_duration           float64
# num_kids                    float64
# dtype: object

# %% [markdown]
# ## **Converting to DateTime data**

# %%
divorce["marriage_date"] = pd.to_datetime(divorce["marriage_date"])
divorce.dtypes
# Out:
# divorce_date         datetime64[ns]
# dob_man                      object
# education_man                object
# income_man                  float64
# dob_woman                    object
# education_woman              object
# income_woman                float64
# marriage_date        datetime64[ns]
# marriage_duration           float64
# num_kids                    float64
# dtype: object

# %% [markdown]
# ## **Creating DateTime data**
#
# * If a dataframe has month, day, and year data

# %%
# Columns must be named month, day, year but in any order
df = pd.DataFrame(data={'month':[6, 2], 'day':[26, 2], 'year':[2000, 2000]})
df['date'] = pd.to_datetime(df[['month', 'day', 'year']])
df
# Out:
#    month  day  year       date
# 0      6   26  2000 2000-06-26
# 1      2    2  2000 2000-02-02

# %% [markdown]
# ## **Extracting date component**

# %%
divorce['marriage_month'] = divorce['marriage_date'].dt.month
divorce[['marriage_date', 'marriage_month']].head()
# Out:
#   marriage_date  marriage_month
# 0    2000-06-26               6
# 1    2001-09-02               9
# 2    2000-02-02               2
# 3    2006-05-13               5
# 4    2007-08-06               8

# %% [markdown]
# ## **Visualizing patterns over time**
#
# * คล้ายๆการ grouped by month plot ค่า mean และช่วงความเชื่อมั่น

# %%
divorce["marriage_month"] = divorce["marriage_date"].dt.month
sns.lineplot(data=divorce, x="marriage_month", y="marriage_duration")
plt.show()

# %% [markdown]
# Create a line plot showing the average number of kids a couple had during their marriage, arranged by the year that the couple got married.

# %%
# Define the marriage_year column
divorce["marriage_year"] = divorce["marriage_date"].dt.year

# Create a line plot showing the average number of kids by year
sns.lineplot(data=divorce, x='marriage_year', y='num_kids')
plt.show()

# %% [markdown]
#  It looks like couples who had later marriage years also had fewer children during their marriage.
#
#  # **Correlation**
# $$r = \frac{\displaystyle\sum_{i=1}^n(X_i - \bar{X})(Y_i-\bar{Y})}{\sqrt{\displaystyle\sum_{i=1}^n(X_i-\bar{X})^2\displaystyle\sum_{i=1}^n(Y_i-\bar{Y})^2}}$$
#  - Pearson correlation
#  - Only <u>***linear***</u> relationship

# %%
divorce = pd.read_csv('divorce.csv', parse_dates=['divorce_date', 'dob_man', 'dob_woman', 'marriage_date'])
divorce["marriage_year"] = divorce["marriage_date"].dt.year

# %%
# Example

X = divorce['income_man']
Y = divorce['income_woman']
XX = X - X.mean()
YY = Y - Y.mean()
XXYY = XX * YY
round(np.sum((X - X.mean()) * (Y - Y.mean())) / (np.sqrt(np.sum((X - X.mean())**2) * np.sum((Y - Y.mean())**2))), 2)
# Out:
# np.float64(0.32)

# %%
divorce.corr(numeric_only=True)
# Out:
#                    income_man  income_woman  marriage_duration  num_kids  \
# income_man               1.00          0.32               0.09      0.04
# income_woman             0.32          1.00               0.08     -0.02
# marriage_duration        0.09          0.08               1.00      0.45
# num_kids                 0.04         -0.02               0.45      1.00
# marriage_year            0.02          0.03              -0.81     -0.46
#
#                    marriage_year
# income_man                  0.02
# income_woman                0.03
# marriage_duration          -0.81
# num_kids                   -0.46
# marriage_year               1.00

# %% [markdown]
# ## **Correlation heatmaps**

# %%
sns.heatmap(divorce.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# ## **Correlation in context**
#
# - Correlation must be interpreted basd on context of data
# - For example,

# %%
print(divorce['divorce_date'].min())
print(divorce['divorce_date'].max())
# Out:
# 2000-01-08 00:00:00
# 2015-11-03 00:00:00

# %% [markdown]
# Although `marriage_year` has strong negative correlation with `marriage_duration`, the availability of the data indicates that data collected in later year must by definition has shorter marriage duration.  Thus, the higher the value of `marriage_year`, the shorther the value of `marriage_duration`.

# %% [markdown]
# ## **Only <u>linear</u> relationship can be captured**

# %%
X = np.linspace(-100, 100, 40)
Y = -X**2
round(np.sum((X - X.mean()) * (Y - Y.mean())) / (np.sqrt(np.sum((X - X.mean())**2) * np.sum((Y - Y.mean())**2))), 2)
# Out:
# np.float64(-0.0)

# %%
# Strong non-linear relationship
plt.plot(X, Y, linestyle='', marker='*'); plt.show()

# %% [markdown]
# ## **Scatter Plots**

# %%
sns.scatterplot(data=divorce, x="income_man", y="income_woman")
plt.show()

# %% [markdown]
# ## **Pair Plots**
#
# - All pairwise relationships between numerical variables
# - The diagonal is the distribution of each variable

# %%
# Add marriage_month to demonstrate how overwhelmed numerical data could be
divorce = pd.read_csv('divorce.csv', parse_dates=['divorce_date', 'dob_man', 'dob_woman', 'marriage_date'])
divorce['marriage_month'] = divorce['marriage_date'].dt.month
divorce['marriage_year'] = divorce['marriage_date'].dt.year
sns.pairplot(data=divorce)
plt.show()

# %% [markdown]
# We can limit the nu,ber of plots to make pairplots look manageable.

# %%
sns.pairplot(data=divorce, vars=["income_man", "income_woman", "marriage_duration"])
plt.show()

# %% [markdown]
# The above pairplots tell us that
#
# - income is slightly correlated with `marriage_duration`
# - There are a lot more short `marriage_duration` than long `marriage_daration`

# %% [markdown]
# # **Categorical relationships**
#
# ถ้ามีหลายกลุ่ม histogram ไม่ค่อยชัดเจน ใช้ kdeplot ดีกว่า

# %%
df = divorce['education_man'].value_counts()
df = df.to_frame()
df
# Out:
#                count
# education_man
# Professional    1313
# Preparatory      501
# Secondary        288
# Primary          100
# Other              3

# %%
sns.barplot(data=df, x=df.index, y='count', hue='count'); plt.show()

# %% [markdown]
# - The above show that we have a lot of observations on `'Professional'`
# - Categorical variables are harder to visualize numerically.
# - Other than count plot above, we usually plot relationship between the categorical variables with other numerical variables

# %%
d = divorce.groupby('education_man', as_index=False)['marriage_duration'].mean().sort_values(by='marriage_duration', ascending=False)
sns.barplot(data=d, x='education_man', y='marriage_duration', hue='education_man'); plt.show()

# %%
sns.histplot(data=divorce, x='marriage_duration', binwidth=1); plt.show()

# %%
sns.histplot(data=divorce, x="marriage_duration", hue="education_man", binwidth=1)
plt.show()

# %%
sns.boxplot(data=divorce, x='education_man', y='marriage_duration',
            order=['Primary', 'Secondary','Preparatory', 'Professional', 'Other'],
            hue='education_man')
plt.show()

# %%
sns.kdeplot(data=divorce, x="marriage_duration", hue="education_man")
plt.show()

# %% [markdown]
# รูปข้างบนนี้มี `marriage_duration` น้อยกว่าศูนย์ ต้องแก้ไขโดยการใส่ `cut=0`

# %%
sns.kdeplot(data=divorce, x="marriage_duration", hue="education_man", cut=0)
plt.show()

# %% [markdown]
# ## **Cumulative KDE plots**
#
# ใส่ `cumulative=True`

# %%
sns.kdeplot(data=divorce, x="marriage_duration", hue="education_man", cut=0, cumulative=True)
plt.show()

# %% [markdown]
# # **Scatter plot with categorical variables**
#
# Is there any relationship between marriage age and educations?

# %%
divorce["man_age_marriage"] = divorce["marriage_year"] - divorce["dob_man"].dt.year
divorce["woman_age_marriage"] = divorce["marriage_year"] - divorce["dob_woman"].dt.year

sns.scatterplot(data=divorce, x="woman_age_marriage", y="man_age_marriage",
                hue="education_man", palette="Set2")
plt.show()

# %% [markdown]
# - Recall that you can introduce the "shape" of tne dots in scatterplot to be indicative of the fourth categorical variable.  So a scatterplot can actually display 4 variables in one figure.
#
# The results suggest that men with a professional education level, represented with orange dots, may tend to get married later.
#
# ### ***Exercise: Categorical data in scatter plots***
#
# In the video, we explored how men's education and age at marriage related to other variables in our dataset, the `divorce` DataFrame. Now, you'll take a look at how *women*'s education and age at marriage relate to other variables!
#
# Your task is to create a scatter plot of each woman's age and income, layering in the categorical variable of education level for additional context.
#
# ##### **Instructions**
#
# Create a scatter plot that shows `woman_age_marriage` on the x-axis and `income_woman` on the y-axis; each data point should be colored based on the woman's level of education, represented by `education_woman`.

# %%
divorce = pd.read_csv('divorce.csv', parse_dates=['divorce_date', 'dob_man', 'dob_woman', 'marriage_date'])
divorce['marriage_month'] = divorce['marriage_date'].dt.month
divorce['marriage_year'] = divorce['marriage_date'].dt.year
divorce["man_age_marriage"] = divorce["marriage_year"] - divorce["dob_man"].dt.year
divorce["woman_age_marriage"] = divorce["marriage_year"] - divorce["dob_woman"].dt.year

sns.scatterplot(data=divorce, x='woman_age_marriage', y='income_woman',
                hue='education_woman', palette="Set2")
plt.show()

# %% [markdown]
# It looks like there is a positive correlation between professional education and higher salaries, as orange dots are placed more at higher income. The relationship between women's age at marriage and education level is a little less clear as all colors of dots seems to spread everywhere.
#
# ### ***Exercise: KDE plots***
#
# Kernel Density Estimate (KDE) plots are a great alternative to histograms when you want to show *multiple distributions* in the same visual.
#
# Suppose you are interested in the relationship between marriage duration and the number of kids that a couple has. Since values in the `num_kids` column range only from one to five, you can plot the KDE for each value on the same plot.
#
# Recall that the `num_kids` column in `divorce` lists only `N/A` values for couples with no children, so you'll only be looking at distributions for divorced couples with at least one child.
#
# ##### **Instructions**
# - Create a KDE plot that shows `marriage_duration` on the x-axis and a different colored line for each possible number of children that a couple might have, represented by `num_kids`, taking into account that the number of kids cannot be less than 1 in this plot.

# %%
sns.kdeplot(data=divorce, x="marriage_duration", hue="num_kids", cut=0)
plt.show()

# %% [markdown]
# - Show a cumulative distribution function for each number of children a couple has.

# %%
sns.kdeplot(data=divorce, x="marriage_duration", hue="num_kids", cut=0, cumulative=True)
plt.show()

# %% [markdown]
# It looks as though there is a positive correlation between longer marriages and more children as the distributions of higher `num_kids` result in the kde plots shifting to the right (longer marriage duration). but of course, <u>***this doesn't indicate causation***</u>.
#
# You can also see that there is much less data on couples with more than two children. This helps us understand how reliable our findings are.
#
# ## **Class imbalance**
#
# ![image.png](data:image/png;base64,...)
#
# * ตัวแปรตาม ไม่ balance กัน เมื่อมี label ใดๆที่มีจำนวนมากกว่า label อื่นในสัดส่วนที่มาก
#
# # **Cross Tabulation**
#
# ![image.png](data:image/png;base64,...)
#
# Examine the combination of frequencies, as well as find aggregated statistics.

# %% [markdown]
# ## **Relative class frequency**

# %%
planes = pd.read_csv('planes.csv')
planes['Destination'].value_counts(normalize=True)
# Out:
# Destination
# Cochin      0.43
# Banglore    0.27
# Delhi       0.12
# New Delhi   0.09
# Hyderabad   0.07
# Kolkata     0.04
# Name: proportion, dtype: float64

# %%
# count of combined observation
pd.crosstab(df["column as index"], df["column"])

# aggregate function
pd.crosstab(df["column as index"], df["column"],
            values=df["numeric_column_of_interest"], aggfunc="some agg func")

# %% [markdown]
# ## **Cross-tabulation: Count**

# %%
pd.crosstab(planes['Source'], planes['Destination'])
# Out:
# Destination  Banglore  Cochin  Delhi  Hyderabad  Kolkata  New Delhi
# Source
# Banglore            0       0   1199          0        0        868
# Chennai             0       0      0          0      364          0
# Delhi               0    4318      0          0        0          0
# Kolkata          2720       0      0          0        0          0
# Mumbai              0       0      0        662        0          0

# %% [markdown]
# ## **Cross-tabulation: Values**

# %%
pd.crosstab(planes['Source'], planes['Destination'], values=planes['Price'], aggfunc='median')
# Out:
# Destination  Banglore    Cochin    Delhi  Hyderabad  Kolkata  New Delhi
# Source
# Banglore          NaN       NaN 4,823.00        NaN      NaN  10,976.50
# Chennai           NaN       NaN      NaN        NaN 3,850.00        NaN
# Delhi             NaN 10,262.00      NaN        NaN      NaN        NaN
# Kolkata      9,345.00       NaN      NaN        NaN      NaN        NaN
# Mumbai            NaN       NaN      NaN   3,342.00      NaN        NaN

# %% [markdown]
# ### ***Exercise: Checking for class imbalance***
#
# The [2022 Kaggle Survey](https://www.kaggle.com/kaggle-survey-2022) captures information about data scientists' backgrounds, preferred technologies, and techniques. It is seen as an accurate view of what is happening in data science based on the volume and profile of responders.
#
# Having looked at the job titles and categorized to align with our salaries DataFrame, you can see the following proportion of job categories in the Kaggle survey:
#
#
# ```
# Job Category	    Relative Frequency
# Data Science	        0.281236
# Data Analytics	        0.224231
# Other	                0.214609
# Managerial	            0.121300
# Machine Learning	    0.083248
# Data Engineering	    0.075375
# ```
#
# Thinking of the Kaggle survey results <ins>*as the population*</ins>, your task is to find out whether the `salaries` DataFrame is representative by comparing the relative frequency of job categories.
#
# * Print the relative frequency of the `"Job_Category"` column from `salaries` DataFrame.

# %%
salaries = pd.read_csv("ds_salaries_clean.csv")
job_categories = ["Data Science", "Data Analytics", "Data Engineering",
                  "Machine Learning", "Managerial", "Consultant"]

data_science = "Data Scientist|NLP"
data_analyst = "Analyst|Analytics"
data_engineer = "Data Engineer|ETL|Architect|Infrastructure"
ml_engineer = "Machine Learning|ML|Big Data|AI"
manager = "Manager|Head|Director|Lead|Principal|Staff"
consultant = "Consultant|Freelance"

conditions = [(salaries["Designation"].str.contains(data_science)),
              (salaries["Designation"].str.contains(data_analyst)),
              (salaries["Designation"].str.contains(data_engineer)),
              (salaries["Designation"].str.contains(ml_engineer)),
              (salaries["Designation"].str.contains(manager)),
              (salaries["Designation"].str.contains(consultant))]

salaries["Job_Category"] = np.select(conditions,
                                     job_categories,
                                     default="Other")

# %%
salaries["Job_Category"].value_counts(normalize=True)
# Out:
# Job_Category
# Data Engineering   0.29
# Data Science       0.26
# Data Analytics     0.22
# Machine Learning   0.12
# Other              0.05
# Managerial         0.05
# Consultant         0.01
# Name: proportion, dtype: float64

# %% [markdown]
# It looks like *Data Science* is the most popular class and has a similar representation. Still, the other categories have quite different relative frequencies.  Given the difference in relative frequencies, can you trust the `salaries` DataFrame to accurately represent Managerial roles?
#
# ### ***Exercise: Cross-tabulation***
#
# Cross-tabulation can help identify how observations occur in combination.
#
# Using the `salaries` dataset, which has been imported as a pandas DataFrame, you'll perform cross-tabulation on multiple variables, including the use of aggregation, to see the relationship between `"Company_Size"` and other variables.
#
# * Perform cross-tabulation, setting `"Company_Size"` as the index, and the columns to classes in `"Experience"`.

# %%
# Cross-tabulate Company_Size and Experience
print(pd.crosstab(salaries["Company_Size"], salaries["Experience"]))

# ใช้ pivot_table ก็ได้เช่นกัน
print(salaries.pivot_table(index="Company_Size", columns="Experience", aggfunc='size'))
# Out:
# Experience    Entry  Executive  Mid  Senior
# Company_Size
# L                29         11   86      72
# M                30         12   98     186
# S                29          3   29      22
# Experience    Entry  Executive  Mid  Senior
# Company_Size
# L                29         11   86      72
# M                30         12   98     186
# S                29          3   29      22

# %% [markdown]
# * Cross-tabulate `"Job_Category"` and classes of `"Company_Size"` as column names.

# %%
# Cross-tabulate Job_Category and Company_Size
print(pd.crosstab(salaries["Job_Category"], salaries["Company_Size"]))
print(salaries.pivot_table(index='Job_Category', columns='Company_Size', aggfunc='size'))
# Out:
# Company_Size       L    M   S
# Job_Category
# Consultant         3    1   3
# Data Analytics    32   91  12
# Data Engineering  54  107  14
# Data Science      56   81  23
# Machine Learning  25   25  22
# Managerial        14   11   3
# Other             14   10   6
# Company_Size       L    M   S
# Job_Category
# Consultant         3    1   3
# Data Analytics    32   91  12
# Data Engineering  54  107  14
# Data Science      56   81  23
# Machine Learning  25   25  22
# Managerial        14   11   3
# Other             14   10   6

# %% [markdown]
# * Update **`pd.crosstab()`** to return the mean `"Salary_USD"` values.

# %%
# Cross-tabulate Job_Category and Company_Size
print(pd.crosstab(salaries["Job_Category"], salaries["Company_Size"],
            values=salaries["Salary_USD"], aggfunc="mean"), "\n\n")

print(salaries.pivot_table(index='Job_Category', columns='Company_Size',
                           values='Salary_USD', aggfunc=np.mean))
# Out:
# Company_Size                  L              M             S
# Job_Category
# Consultant         77553.000000    5449.000000  75296.333333
# Data Analytics    102997.125000   98125.835165  43074.500000
# Data Engineering  113829.888889  116668.971963  85645.285714
# Data Science      107865.303571  121664.888889  70426.869565
# Machine Learning  123878.520000  100849.480000  85124.954545
# Managerial        170102.857143  160419.454545  98976.333333
# Other              96392.928571   83067.000000  70195.166667
#
#
# Company_Size                  L              M             S
# Job_Category
# Consultant         77553.000000    5449.000000  75296.333333
# Data Analytics    102997.125000   98125.835165  43074.500000
# Data Engineering  113829.888889  116668.971963  85645.285714
# Data Science      107865.303571  121664.888889  70426.869565
# Machine Learning  123878.520000  100849.480000  85124.954545
# Managerial        170102.857143  160419.454545  98976.333333
# Other              96392.928571   83067.000000  70195.166667

# %% [markdown]
# Looks like the largest mean salary is for Managerial data roles in large companies!
#
# # **Generating new features**

# %%
planes = pd.read_csv('planes.csv'); planes['Duration'].head()

# Missing data must be dealt with since .transform cannot be used
threshold = len(planes) * 0.05
cols_to_drop = planes.columns[planes.isnull().sum() <= threshold]
planes.dropna(subset=cols_to_drop, inplace=True)
airline_prices = planes.groupby("Airline")["Price"].median()
prices_dict = airline_prices.to_dict()
planes["Price"] = planes["Price"].fillna(planes["Airline"].map(prices_dict))

# Convert Duration column into float
planes['Duration'] = planes['Duration'].str.replace('h|m', '', regex=True)
planes['Duration'] = planes['Duration'].str.split()
planes['Hours'] = planes['Duration'].transform(lambda x: x[0]).astype('float')
planes['Mins'] = planes['Duration'].transform(lambda x: 0 if len(x) == 1 else x[1]).astype('float')
planes['Duration'] = planes['Hours'] + planes['Mins']/ 60

sns.heatmap(planes[['Price', 'Duration']].corr(numeric_only=True), annot=True); plt.show()

# %% [markdown]
# According to data types above, there are only 2 numeric columns to calculate correlation.

# %% [markdown]
# `Total_Stops` should be numeric

# %%
planes['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      4467
# non-stop    2786
# 2 stops     1219
# 3 stops       35
# 4 stops        1
# Name: count, dtype: int64

# %% [markdown]
# ## **Change string column to numeric**

# %%
planes['Total_Stops'] = planes['Total_Stops'].str.replace(' stops','').str.replace(' stop', '').str.replace('non-stop','0').fillna(0).astype(int)
print(planes['Total_Stops'].dtype)
planes['Total_Stops'].value_counts()
# Out:
# int64
# Total_Stops
# 1    4467
# 0    2786
# 2    1219
# 3      35
# 4       1
# Name: count, dtype: int64

# %% [markdown]
# Now we can see correlation of total stops

# %%
sns.heatmap(planes[['Duration', 'Total_Stops', 'Price']].corr(), annot=True)
plt.show()

# %% [markdown]
# ## **Extrracting `month` and `weekday`**
#
# - See whether month, weekday, hour are correlated with price

# %%
planes['month'] = planes['Date_of_Journey'].dt.month
planes['weekday'] = planes['Date_of_Journey'].dt.weekday
planes['Dep_Hour'] = planes['Dep_Time'].dt.hour
planes['Arrival_Hour'] = planes['Arrival_Time'].dt.hour
planes[['month', 'weekday', 'Date_of_Journey']].head()
# Out:
#    month  weekday Date_of_Journey
# 0    6.0      6.0      2019-06-09
# 1    5.0      6.0      2019-05-12
# 2    3.0      4.0      2019-03-01
# 3    6.0      0.0      2019-06-24
# 4    3.0      1.0      2019-03-12

# %%
sns.heatmap(planes.select_dtypes(include=['number']).corr(), annot=True)
plt.show()

# %% [markdown]
# # **Build categorical variable from numerics**

# %%
twenty_fifth = planes["Price"].quantile(0.25)
median = planes["Price"].median()
seventy_fifth = planes["Price"].quantile(0.75)
maximum = planes["Price"].max()

# สร้าง bins
labels = ["under 25", "25-50", "51-75", "76-100"]
labels = ["Economy", "Premium Economy", "Business Class", "First Class"]
bins = [0, twenty_fifth, median, seventy_fifth, maximum]

# %% [markdown]
# ## **`pd.cut()`**
#
# ![image.png](data:image/png;base64,...)

# %%
planes["price_category"] = pd.cut(planes["Price"], labels=labels, bins=bins)
planes[['Price', 'price_category']].head()
# Out:
#       Price   price_category
# 0 13,882.00      First Class
# 1  6,218.00  Premium Economy
# 2 13,302.00      First Class
# 3  3,873.00          Economy
# 4 11,087.00   Business Class

# %% [markdown]
# ## **Count plot for each category**

# %%
# ตัวอย่าง

sns.countplot(data=planes, x="Airline", hue="price_category", palette='Set2')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Looks like Jet Airways has the highest number of "First Class"
# - MOst of IndiGo and SpiceJet flights are "Economy".

# %% [markdown]
# ### ***Exercise: Extracting features for correlation***
#
# In this exercise, you'll work with a version of the `salaries` dataset containing a new column called `"date_of_response"`.
#
# The dataset has been read in as a pandas DataFrame, with `"date_of_response"` as a datetime data type.
#
# Your task is to extract datetime attributes from this column and then create a heat map to visualize the correlation coefficients between variables.
#
# * Extract the month from `"date_of_response"`, storing it as a column called `"month"`.
#
# * Create the `"weekday"` column, containing the weekday that the participants completed the survey.
#
# * Plot a heat map, including the Pearson correlation coefficient scores.

# %%
# Get the month of the response
salaries["month"] = salaries["date_of_response"].dt.month

# Extract the weekday of the response
salaries["weekday"] = salaries["date_of_response"].dt.dayofweek

# Create a heatmap
sns.heatmap(salaries.corr(), annot=True)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Looks like there aren't any meaningful relationships between our numeric variables, so let's see if converting numeric data into classes offers additional insights.
#
# ### ***Exercise: Calculating salary percentiles***
#
# In the video, you saw that the conversion of numeric data into categories sometimes makes it easier to identify patterns.
#
# Your task is to convert the `"Salary_USD"` column into categories based on its percentiles. First, you need to find the percentiles and store them as variables.
#
# **`pandas`** has been imported as `pd` and the salaries dataset read in as DataFrame called `salaries`.
#
# ##### ***Instructions***
#
# - Find the 25th percentile of `"Salary_USD"`.
# - Store the median of `"Salary_USD"` as `salaries_median`.
# - Get the 75th percentile of `salaries`.

# %%
# Find the 25th percentile
twenty_fifth = salaries["Salary_USD"].quantile(0.25)

# Save the median
salaries_median = salaries["Salary_USD"].median()

# Gather the 75th percentile
seventy_fifth = salaries["Salary_USD"].quantile(0.75)
print(twenty_fifth, salaries_median, seventy_fifth)
# Out:
# 59893.0 96982.0 143225.0

# %% [markdown]
# Looks like the interquartile range is between 59,893 and 143,225 dollars! Now let's use these variables to add a categorical salary column into the DataFrame.
#
# ### ***Exercise: Categorizing salaries***
#
# Now it's time to make a new category! You'll use the variables `twenty_fifth`, `salaries_median`, and `seventy_fifth`, that you created in the previous exercise, to split salaries into different labels.
#
# The result will be a new column called `"salary_level"`, which you'll incorporate into a visualization to analyze survey respondents' salary and at companies of different sizes.
#
# ##### ***Instructions***
#
# - Create `salary_labels`, a list containing `"entry"`, `"mid"`, `"senior"`, and `"exec"`.
# - Finish `salary_ranges`, adding the 25th percentile, median, 75th percentile, and largest value from `"Salary_USD"`.
# - Split `"Salary_USD"` based on the labels and ranges you've created.
# - Use **`sns.countplot()`** to visualize the count of `"Company_Size"`, factoring salary level labels.

# %%
# Create salary labels
salary_labels = ["entry", "mid", "senior", "exec"]

# Create the salary ranges list
salary_ranges = [0, twenty_fifth, salaries_median, seventy_fifth, salaries["Salary_USD"].max()]

# Create salary_level
salaries["salary_level"] = pd.cut(salaries["Salary_USD"],
                                  bins=salary_ranges,
                                  labels=salary_labels)

# Plot the count of salary levels at companies of different sizes
sns.countplot(data=salaries, x="Company_Size", hue="salary_level", order=['S', 'M', 'L'], palette='Set2')
plt.show()

# %% [markdown]
# By using **`pd.cut()`** to split out numeric data into categories, you can see that a large proportion of workers at small companies get paid `"entry"` level salaries, while more staff at medium-sized companies are rewarded with `"senior"` level salary. Now let's look at generating hypotheses as you reach the end of the EDA phase.
#
# # **Hypothesis**
#
# What do we know about planes dataset?
#
# - A large proportion of Jet Airways' ticket are expensive.

# %%
sns.countplot(data=planes, x="Airline", hue="price_category")
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# Duration, total stops, and price are moderately correlated, but no other meaningful relationship exists.

# %%
sns.heatmap(planes.select_dtypes(include=['number']).corr(), annot=True)
plt.show()

# %% [markdown]
# It looks like `Total_Stops` largely depends on `Duration`.  We might think `Total_Stops` is correlated with `Price` but in fact it is just `Duration` that is correlated and `Total_Stops` mostly maps to `Duration` ranges.

# %%
sns.scatterplot(data=planes, x='Duration', y='Price', hue='Total_Stops')
plt.show()

# %%
sns.scatterplot(data=planes, x='Duration', y='Total_Stops')
plt.show()

# %% [markdown]
# That's why we need to use hypothesis to test whether what we are concerned is true of false.
#
# ## **Generating Hypothesis**
#
# Do Jet Airways flights last longer than SpiceJet?

# %%
sns.barplot(data=planes, x='Airline', y='Duration',
            order=['Air India', 'Jet Airways', 'Multiple carriers', 'Vistara', 'Air Asia', 'GoAir', 'IndiGo', 'SpiceJet'], hue='Airline', palette='Set2')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Are flights to New Delhi more expensive than other destinations on average?

# %%
sns.barplot(data=planes, x='Destination', y='Price', order=['New Delhi', 'Cochin', 'Banglore', 'Delhi', 'Hyderabad', 'Kolkata'], hue='Destination', palette='Set2')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We need to design experiment.
#
# - Choosing a sample
# - Calculating how many data points we need
# - Deciding what statistical tests to run

# %% [markdown]
# ### ***Exercise: Comparing salaries***
#
# Exploratory data analysis is a crucial step in generating hypotheses!
#
# Do data professionals get paid more in the USA than they do in Great Britain?
#
# You'll need to subset the data by `"Employee_Location"` and produce a plot displaying the average salary between the two groups.

# %%
# Filter for employees in the US or GB

salaries = pd.read_csv('/content/ds_salaries_clean.csv')
usa_and_gb = salaries[salaries["Employee_Location"].isin(["US", "GB"])]

# Create a barplot of salaries by location
sns.barplot(data=usa_and_gb, x="Employee_Location", y="Salary_USD", hue='Employee_Location')
plt.show()

# %%
usa_and_gb.groupby("Employee_Location")['Salary_USD'].mean()
# Out:
# Employee_Location
# GB    77,726.48
# US   142,455.64
# Name: Salary_USD, dtype: float64

# %% [markdown]
# By subsetting the data you were able to directly compare salaries between the USA and Great Britain. The visualization suggests you've generated a hypothesis that is worth formally investigating to determine whether a real difference exists or not!
#
# ### ***Exercise: Choosing a hypothesis***
# You've seen how visualizations can be used to generate hypotheses, making them a crucial part of exploratory data analysis!
#
# In this exercise, you'll generate a bar plot to inspect how salaries differ based on company size and employment status.
#
#
#
# ```
# Value	Meaning
# CT	Contractor
# FL	Freelance
# PT	Part-time
# FT	Full-time
# ```

# %%
# Create a bar plot of salary versus company size, factoring in employment status
sns.barplot(data=salaries, x="Company_Size", y="Salary_USD", hue="Employment_Status")
plt.show()

# %%
# The above graph also comes from
salaries.groupby(["Company_Size", 'Employment_Status'])['Salary_USD'].mean().to_frame()
# Out:
#                                 Salary_USD
# Company_Size Employment_Status
# L            CT                 176,644.00
#              FL                  19,097.00
#              FT                 114,260.58
#              PT                  59,533.00
# M            CT                  65,346.50
#              FL                  53,470.50
#              FT                 113,302.61
#              PT                  30,498.00
# S            CT                 397,211.00
#              FL                  57,290.00
#              FT                  73,029.52
#              PT                  18,677.50

# %% [markdown]
# - What is a reasonable hypothesis to generate based on this plot?
# (Note that our data generates a little bit different figures.)
#
# ![image.png](data:image/png;base64,...)
#
# On average, do large companies pay contractors more than medium-sized companies?  Contractors appear to be paid more by large companies on average based on the data, so this is a reasonable hypothesis.
